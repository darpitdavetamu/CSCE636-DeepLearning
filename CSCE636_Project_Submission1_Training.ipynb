# %%
# # %%capture
# import os
# from os.path import exists, join, basename, splitext

# git_repo_url = 'https://github.com/CMU-Perceptual-Computing-Lab/openpose.git'
# project_name = splitext(basename(git_repo_url))[0]
# if not exists(project_name):
#   # see: https://github.com/CMU-Perceptual-Computing-Lab/openpose/issues/949
#   # install new CMake becaue of CUDA10
#   !wget -q https://cmake.org/files/v3.13/cmake-3.13.0-Linux-x86_64.tar.gz
#   !tar xfz cmake-3.13.0-Linux-x86_64.tar.gz --strip-components=1 -C /usr/local
#   # clone openpose
#   !git clone -q --depth 1 $git_repo_url
#   !sed -i 's/execute_process(COMMAND git checkout master WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/execute_process(COMMAND git checkout f019d0dfe86f49d1140961f8c7dec22130c83154 WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/g' openpose/CMakeLists.txt
#   # install system dependencies
#   !apt-get -qq install -y libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev opencl-headers ocl-icd-opencl-dev libviennacl-dev
#   # install python dependencies
#   !pip install -q youtube-dl
#   # build openpose
#   !cd openpose && rm -rf build || true && mkdir build && cd build && cmake .. && make -j`nproc`

# %%
# Importing libraries for embedding the video in Jupyter Notebook cell
import io
import base64
from IPython.display import HTML
# Importing libraries to download youtube videos
from IPython.display import YouTubeVideo
from google.colab import drive

# %%
# For mouting Google drive to be used for data
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Sample video conversion (uncomment to check and use)
#!./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/112.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/JSON_Output/sample_output112.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/1.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/1.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/1/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/2.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/2.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/2/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/3.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/3.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/3/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/4.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/4.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/4/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/5.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/5.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/5/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/6.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/6.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/6/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/7.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/7.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/7/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/8.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/8.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/8/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/9.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/9.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/9/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/10.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/10.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/10/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/11.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/11.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/11/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/12.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/12.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/12/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/13.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/13.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/13/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/14.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/14.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/14/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/15.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/15.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/15/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/16.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/16.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/16/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/17.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/17.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/17/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/18.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/18.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/18/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/19.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/19.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/19/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/20.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/20.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/20/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/21.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/21.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/21/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/22.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/22.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/22/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/23.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/23.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/23/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/24.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/24.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/24/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/25.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/25.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/25/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/26.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/26.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/26/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/27.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/27.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/27/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/28.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/28.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/28/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/29.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/29.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/29/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/30.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/30.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/30/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/31.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/31.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/31/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/32.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/32.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/32/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/33.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/33.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/33/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/34.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/34.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/34/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/35.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/35.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/35/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/36.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/36.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/36/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/37.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/37.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/37/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/38.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/38.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/38/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/39.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/39.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/39/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/40.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/40.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/40/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/41.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/41.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/41/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/42.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/42.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/42/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/43.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/43.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/43/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/44.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/44.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/44/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/45.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/45.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/45/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/46.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/46.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/46/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/47.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/47.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/47/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/48.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/48.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/48/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/49.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/49.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/49/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/50.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/50.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/50/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/51.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/51.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/51/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/52.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/52.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/52/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/53.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/53.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/53/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/54.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/54.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/54/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/55.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/55.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/55/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/56.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/56.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/56/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/57.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/57.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/57/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/58.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/58.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/58/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/59.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/59.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/59/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/60.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/60.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/60/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/61.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/61.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/61/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/62.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/62.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/62/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/63.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/63.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/63/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/64.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/64.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/64/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/65.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/65.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/65/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/66.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/66.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/66/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/67.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/67.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/67/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/68.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/68.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/68/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/69.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/69.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/69/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/70.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/70.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/70/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/71.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/71.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/71/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/72.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/72.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/72/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/73.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/73.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/73/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/74.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/74.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/74/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/75.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/75.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/75/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/76.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/76.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/76/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/77.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/77.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/77/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/78.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/78.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/78/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/79.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/79.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/79/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/80.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/80.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/80/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/81.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/81.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/81/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/82.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/82.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/82/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/83.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/83.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/83/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/84.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/84.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/84/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/85.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/85.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/85/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/86.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/86.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/86/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/87.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/87.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/87/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/88.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/88.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/88/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/89.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/89.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/89/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/90.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/90.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/90/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/91.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/91.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/91/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/92.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/92.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/92/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/93.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/93.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/93/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/94.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/94.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/94/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/95.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/95.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/95/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/96.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/96.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/96/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/97.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/97.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/97/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/98.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/98.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/98/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/99.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/99.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/99/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/90.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/100.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/100/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/101.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/101.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/101/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/102.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/102.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/102/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/103.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/103.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/103/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/104.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/104.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/104/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/105.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/105.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/105/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/106.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/106.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/106/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/107.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/107.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/107/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/108.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/108.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/108/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/109.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/109.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/109/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/110.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/110.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/110/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/111.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/111.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/111/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/112.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/112.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/112/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/113.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/113.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/113/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/114.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/114.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/114/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/115.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/115.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/115/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/116.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/116.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/116/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/117.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/117.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/117/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/118.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/118.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/118/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/119.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/119.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/119/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/120.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/120.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/120/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/121.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/121.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/121/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/122.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/122.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/122/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/123.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/123.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/123/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/124.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/124.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/124/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/125.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/125.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/125/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/126.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/126.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/126/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/127.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/127.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/127/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/128.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/128.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/128/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/129.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/129.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/129/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/130.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/130.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/130/'} --model_folder openpose/models --disable_blending --display 0

# %%
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/131.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/131.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/131/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/132.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/132.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/132/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/133.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/133.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/133/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/134.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/134.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/134/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/135.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/135.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/135/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/136.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/136.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/136/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/137.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/137.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/137/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/138.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/138.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/138/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/139.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/139.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/139/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/140.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/140.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/140/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/141.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/141.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/141/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/142.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/142.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/142/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/143.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/143.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/143/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/144.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/144.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/144/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/145.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/145.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/145/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/146.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/146.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/146/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/147.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/147.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/147/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/148.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/148.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/148/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/149.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/149.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/149/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/150.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/150.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/150/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/151.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/151.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/151/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/152.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/152.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/152/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/153.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/153.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/153/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/154.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/154.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/154/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/155.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/155.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/155/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/156.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/156.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/156/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/157.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/157.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/157/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/158.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/158.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/158/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/159.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/159.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/159/'} --model_folder openpose/models --disable_blending --display 0
# !./openpose/build/examples/openpose/openpose.bin --video {'/content/drive/My\ Drive/CSCE636/Video_Input/160.mp4'} --write_video {'/content/drive/My\ Drive/CSCE636/Video_Output/160.mp4'} --write_json {'/content/drive/My\ Drive/CSCE636/JSON_Output/160/'} --model_folder openpose/models --disable_blending --display 0

# %%
#Importing Libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional
from keras.layers import Conv1D, MaxPooling1D, Activation
from keras import optimizers
from keras import regularizers
from keras.callbacks import EarlyStopping
import json
import glob
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from tensorflow.keras import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout



# For mouting Google drive to be used for data
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def convert_data(start, end, output_json, output_json_key):
  '''
  start- Starting video number to be added to text file
  end - Last video number to be added
  output_json - Path of json files for videos
  output_json_key -  path of text file where the key-point values are to stored
  '''
  with open(output_json_key,"w") as x:
    for i in range(start, end+1):
          json_files = glob.glob(output_json + '/'+ str(i)+"/*")
          j=0
          for jfile in json_files:
            if j< 140:
              j = j + 1
              with open(jfile) as f:
                  data = json.load(f)
                  if data['people']:
                      kp= data['people'][0]['pose_keypoints_2d']
                      kp = [ str(v) for v in kp]
                      r =','.join(kp)
                      x.write('{}\n'.format(r))

# %%
def read_data(file_name):
  '''
  INPUT: file_name = Text file to be converted ito array
  OUTPUT: data = Return array
  '''
  number = [i for i in range(0, 74) if (i+1) % 3 != 0]
  data = np.loadtxt(file_name, usecols=number, delimiter = ",")
  return data

# %%
def generate_label():
  '''
  OUTPUT: Y_train - Labels for training data
          Y_val - Labels for validation data
  '''
  y = np.zeros(60)
  y = np.append(y, np.ones(80))        #1
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #2
  y = np.append(y, np.zeros(80))
  y = np.append(y, np.ones(60))        #3
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #4
  y = np.append(y, np.zeros(40))
  y = np.append(y, np.ones(100))       #5
  y = np.append(y, np.zeros(60))     
  y = np.append(y, np.ones(80))        #6
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #7
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #8
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #9
  y = np.append(y, np.zeros(60)) 
  y = np.append(y, np.ones(80))        #10
  y = np.append(y, np.zeros(30)) 
  y = np.append(y, np.ones(110))       #11
  y = np.append(y, np.zeros(60)) 
  y = np.append(y, np.ones(80))        #12
  y = np.append(y, np.zeros(2520))     #30
  y = np.append(y, np.zeros(90))
  y = np.append(y, np.ones(50))        #31
  y = np.append(y, np.zeros(40))
  y = np.append(y, np.ones(100))       #32
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #33
  y = np.append(y, np.zeros(30)) 
  y = np.append(y, np.ones(110))       #34
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #35
  y = np.append(y, np.zeros(30)) 
  y = np.append(y, np.ones(110))       #36
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #37
  y = np.append(y, np.zeros(60)) 
  y = np.append(y, np.ones(80))        #38
  y = np.append(y, np.zeros(80))
  y = np.append(y, np.ones(60))        #39
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #40
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #41
  y = np.append(y, np.ones(700))       #46
  y = np.append(y, np.zeros(420))      #49   
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #50
  y = np.append(y, np.zeros(420))      #53
  y = np.append(y, np.ones(840))       #59
  y = np.append(y, np.zeros(3500))     #84
  y = np.append(y, np.ones(840))       #90
  y = np.append(y, np.zeros(40))
  y = np.append(y, np.ones(100))       #91
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #92
  y = np.append(y, np.zeros(70))
  y = np.append(y, np.ones(70))        #93
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #94
  y = np.append(y, np.zeros(40)) 
  y = np.append(y, np.ones(100))       #95
  y = np.append(y, np.zeros(60))
  y = np.append(y, np.ones(80))        #96
  y = np.append(y, np.zeros(50)) 
  y = np.append(y, np.ones(90))        #97
  y = np.append(y, np.zeros(30)) 
  y = np.append(y, np.ones(110))       #98
  y = np.append(y, np.zeros(110))
  y = np.append(y, np.ones(30))        #99
  y = np.append(y, np.zeros(30))
  y = np.append(y, np.ones(110))       #100
  y = np.append(y, np.zeros(1260))       #109
  y = np.append(y, np.ones(1260))       #118
  y = np.append(y, np.zeros(2800))       #138
  y = np.append(y, np.ones(3080))       #160

  Y_train = np.concatenate((y[:9800], y[16520:22400]), axis=0)
  Y_val = y[9800:16520]

  return Y_train,Y_val

# %%
                                  ###DATA CONVERSION (only required once for generating text files)####
#INITIALIZATION:
#TRAINING:
output_json = '/content/drive/My Drive/CSCE636/JSON_Output'
output_json_key_train = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_train.txt"
start = 1                   #training is from video 1 to video 70 --CHANGE
end = 70
Xtrain = convert_data(start, end, output_json, output_json_key_train)    

#VALIDATION:
output_json = '/content/drive/My Drive/CSCE636/JSON_Output'
output_json_key_val = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_val.txt"
start = 71                  #validation is from video 70 to video 100 --CHANGE
end = 100
Xtrain = convert_data(start, end, output_json, output_json_key_val)

                                          ##EXTENSION OF DATASET##
#ADDING MORE TRAINING DATA:
output_json = '/content/drive/My Drive/CSCE636/JSON_Output'
output_json_key_train = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_train_new.txt"
start = 119                   #training is from video 119 to video 160 --CHANGE
end = 160
Xtrain_new = convert_data(start, end, output_json, output_json_key_train)    

#ADDING MORE VALIDATION DATA:
output_json = '/content/drive/My Drive/CSCE636/JSON_Output'
output_json_key_val = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_Val_new.txt"
start = 101                 #validation is from video 101 to video 118 --CHANGE
end = 118
Xval_new = convert_data(start, end, output_json, output_json_key_val)

# %%
#GENERATING TRAINING AND VALIDATION ARRAYS:

#FOR X-file:
train = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_train.txt"   ##CHANGE accordingly while increasing dataset##
X_train = read_data(train) 

train2 = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_train_new.txt"   ##CHANGE accordingly while increasing dataset##
X_train_new = read_data(train2)

X_train = np.concatenate((X_train, X_train_new), axis=0)
X_train = X_train.reshape(1568,10,50) 

val = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_val.txt"   ##CHANGE accordingly while increasing dataset##
X_val = read_data(val) 
val2 = "/content/drive/My Drive/CSCE636/Train_Val_Test/X_Val_new.txt"   ##CHANGE accordingly while increasing dataset##
X_val_new = read_data(val2)
X_val = np.concatenate((X_val, X_val_new), axis=0)
X_val = X_val.reshape(672,10,50)

#FOR Y-file:
Y_train,Y_val = generate_label()
Y_train = Y_train.reshape(1568,10,1)
Y_val = Y_val.reshape(672,10,1)

print('X_training = ', X_train.shape)
print('X_validation = ',X_val.shape)
print('Y_training = ', Y_train.shape)
print('Y_validation = ',Y_val.shape)
# Out:
# X_training =  (1568, 10, 50)
# X_validation =  (672, 10, 50)
# Y_training =  (1568, 10, 1)
# Y_validation =  (672, 10, 1)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#path = '/content/drive/My Drive/CSCE636/Model/Submission1/model1_epochs.{epoch:02d}-{val_accuracy:.2f}.hdf5'
#callbacks_list = tf.keras.callbacks.ModelCheckpoint(path,save_weights_only=False,
#                                                    save_best_only=True,monitor='val_accuracy',
#                                                   patience = 10)
#earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
#mcp_save = ModelCheckpoint('.mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='min')
#reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')
path = '/content/drive/My Drive/CSCE636/Model/Submission1/model_submit1_epochs.{epoch:02d}-{val_accuracy:.2f}.hdf5'
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save = ModelCheckpoint(path, save_best_only=True, monitor='val_loss', mode='min')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, mode='min')

checkpoint = [earlyStopping, mcp_save, reduce_lr_loss]

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(150, input_shape=(10,50), return_sequences=True))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
model.add(tf.keras.layers.LSTM(150, input_shape=(10,50), return_sequences=True))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
model.add(tf.keras.layers.LSTM(150, input_shape=(10,50), return_sequences=True))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
model.add(tf.keras.layers.LSTM(150, input_shape=(10,50), return_sequences=True))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.5)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='sigmoid')))

adam = tf.keras.optimizers.Adam(lr = 0.00001)
model.compile(loss = 'binary_crossentropy', optimizer=adam ,metrics = ['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 10, 150)           120600
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 150)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 150)           180600
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 150)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 150)           180600
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 150)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 150)           180600
# ...

# %%
history = model.fit(X_train, Y_train, batch_size = 20, epochs = 500, verbose = 1, validation_data=(X_val, Y_val), callbacks=checkpoint)
# Out:
# Epoch 1/500
# 79/79 [==============================] - 14s 28ms/step - loss: 1.5884 - accuracy: 0.5686 - val_loss: 1.5767 - val_accuracy: 0.5493
# Epoch 2/500
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5720 - accuracy: 0.5739 - val_loss: 1.5605 - val_accuracy: 0.5518
# Epoch 3/500
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5548 - accuracy: 0.5790 - val_loss: 1.5429 - val_accuracy: 0.5533
# Epoch 4/500
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5347 - accuracy: 0.5928 - val_loss: 1.5236 - val_accuracy: 0.5749
# Epoch 5/500
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5136 - accuracy: 0.6108 - val_loss: 1.5008 - val_accuracy: 0.6057
# Epoch 6/500
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4914 - accuracy: 0.6408 - val_loss: 1.4753 - val_accuracy: 0.6500
# Epoch 7/500
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
#plt.ylim([0,1.2])
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='best')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model train vs validation acc')
plt.ylabel('acc')
#plt.ylim([0.7,1])
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='best')
plt.show()

# %%
pred = model.predict(X_val)

# %%
pred.shape
# Out:
# (672, 10, 1)

# %%
pred_class = []
true_class = []
for i in range(0,pred.shape[0]):
  x = np.mean(pred[i])
  y = np.mean(Y_val[i])
  if x > 0.5:
    pred_class.append(1)
  else:
    pred_class.append(0)
  if y > 0.5:
    true_class.append(1)
  else:
    true_class.append(0)

# %%
import sklearn
acc = sklearn.metrics.accuracy_score(true_class,pred_class)

# %%
acc
# Out:
# 0.8288690476190477

# %%
indices = [i for i, x in enumerate(true_class) if x == 1]

# %%
true_class1 = [true_class[i] for i in indices]
pred_class1 = [pred_class[i] for i in indices]

# %%
sklearn.metrics.accuracy_score(true_class1,pred_class1)
# Out:
# 0.813953488372093

# %%
from keras.utils.vis_utils import plot_model
tf.keras.utils.plot_model(model, to_file = '/content/drive/My Drive/CSCE636/model_plot.png' , show_shapes=True, show_layer_names=True)
