# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
import json
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def read_data(file_name_json):
  '''
  file_name_json - path of json files for videos
  file_name_text -  path of text file where the key-point values are to stored
  '''
  test = []
  j=0
  json_files = glob.glob(file_name_json)
  #print(len(json_files))
  limit = len(json_files)-(len(json_files)%10)
  for jfile in json_files:
    if j < limit:
      j = j + 1
      with open(jfile) as f:
        data = json.load(f)
        if data['people']:
          kp= data['people'][0]['pose_keypoints_2d']
          kp = [kp[i] for i in range(0, 74) if (i+1) % 3 != 0]
          test.append(kp)
  x = int(len(test)/10)
  X_predict = np.asarray(test)
  print(X_predict.shape)
  ans = X_predict.shape[0]%10
  if X_predict.shape[0]%10 != 0:
    X_predict = X_predict[:-ans, :]
  print(X_predict.shape)
  test = test[: len(test) - ans]
  X_predict = X_predict.reshape(x, 10, 50)
  return X_predict, len(test)

# %%
##LOAD THE SAVED MODEL##
model = keras.models.load_model('/content/drive/My Drive/CSCE636/Model/Submission8/model_submit8_final.hdf5')

# %%
#PREDICT THE MODEL#
def predict(file_name_json):
  X_predict, num_frames = read_data(file_name_json)
  ypre = model.predict(X_predict)
  ypre=ypre.flatten()
  df = pd.DataFrame(ypre) 
  rolling = df.rolling(window=10)
  rolling_mean = rolling.mean()
  fps = 30
  x = np.linspace(0,num_frames/fps,num_frames)
  plt.figure(1)
  plt.plot(x, ypre)
  plt.axhline(y=0.5, color='r', linestyle='-')
  plt.ylabel('label')
  plt.xlabel('time in seconds')
  plt.legend(['Actual predicted data'], loc='best' )
  plt.ylim([0,1.2])
  plt.title('Prediction Output For Sample Videos')
  plt.show()

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial1/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial2/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial3/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial4/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial5/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial6/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial7/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial8/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial9/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial10/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial10/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial11/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial12/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial13/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial14/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial15/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial16/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial16/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial17/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial18/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial19/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial20/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial21/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (60, 50)
# (60, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial22/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (60, 50)
# (60, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial23/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial24/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial25/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial26/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial27/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial28/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial30/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial31/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial32/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial33/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial34/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial35/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial36/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial37/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial38/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial39/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial40/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial41/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (38, 50)
# (30, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial42/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial43/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial44/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial45/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial46/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial47/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial48/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial49/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial50/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial51/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial52/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial53/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial54/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial55/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial56/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial57/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial58/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial59/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial60/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial61/*'  #change json file for different test videos
predict(file_name_json)2
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial62/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial63/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial64/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial65/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial66/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial67/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial68/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (40, 50)
# (40, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial69/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (39, 50)
# (30, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial70/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial71/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial72/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)

# %%
file_name_json = '/content/drive/My Drive/CSCE636/Trial_check_submission8/Trial73/*'  #change json file for different test videos
predict(file_name_json)
# Out:
# (50, 50)
# (50, 50)
